# %%
import pickle
import sys
rootPath = '/Users/floyd/Desktop/Research/NER-CRF/cctner'
sys.path.append('/Users/floyd/Desktop/Research/NER-CRF/cctner')

cctListPath = 'pkldata/2017-11-03/R_CCT_List.p'
cctDictPath = 'pkldata/2017-11-03/R_CCT_Dict.p'

with open(cctListPath, 'rb') as handle:
    cctList = pickle.load(handle)
    
with open(cctDictPath, 'rb') as handle:
    cctDict = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a0785f1c7f94> in <module>()
#       9 cctDictPath = 'pkldata/2017-10-23/CCT_Dict.p'
#      10
# ---> 11 with open(cctListPath, 'rb') as handle:
#      12     cctList = pickle.load(handle)
#      13
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pkldata/2017-10-23/CCT_List.p'

# %%
import pickle
import sys
rootPath = '/Users/floyd/Desktop/Research/NER-CRF/cctner'
sys.path.append('/Users/floyd/Desktop/Research/NER-CRF/cctner')

cctListPath = 'pkldata/2017-11-03/R_CCT_List.p'
cctDictPath = 'pkldata/2017-11-03/R_CCT_Dict.p'

with open(cctListPath, 'rb') as handle:
    cctList = pickle.load(handle)
    
with open(cctDictPath, 'rb') as handle:
    cctDict = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6574f5a5a58c> in <module>()
#       7 cctDictPath = 'pkldata/2017-11-03/R_CCT_Dict.p'
#       8
# ----> 9 with open(cctListPath, 'rb') as handle:
#      10     cctList = pickle.load(handle)
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pkldata/2017-11-03/R_CCT_List.p'

# %%
import random

random.seed(10)
l = random.sample(range(300), 75)
l.sort()
l
# Out:
# [2,
#  7,
#  16,
#  17,
#  18,
#  22,
#  33,
#  36,
#  38,
#  41,
#  49,
#  57,
#  68,
#  71,
#  73,
#  76,
#  80,
#  82,
#  85,
#  89,
#  91,
#  97,
#  99,
#  105,
#  114,
#  120,
#  122,
#  125,
#  127,
#  134,
#  140,
#  142,
#  145,
#  154,
#  155,
#  160,
#  166,
#  167,
#  178,
#  181,
#  184,
#  185,
#  187,
#  191,
#  192,
#  195,
#  196,
#  211,
#  212,
#  215,
#  219,
#  221,
#  223,
#  225,
#  226,
#  228,
#  230,
#  233,
#  236,
#  240,
#  247,
#  250,
#  251,
#  254,
#  256,
#  266,
#  267,
#  273,
#  274,
#  281,
#  290,
#  292,
#  295,
#  298,
#  299]

# %%
cct = cctList[0]
cct.originalFilePath
# Out:
# 'annotated/01-一般项目/一般项目-1.txtoriginal.txt'

# %% [markdown]
# ### TrainData

# %%
cct = cctList[109]
cct.getAnnotedEntities('RTag')
cct.coporAnnotation('RTag')
cct.getAnnotedEntities('ETag')
cct.coporAnnotation('ETag')
cct.dfFormat

## We need a pure CCTList now
## As the 102th has been dominished
# Out:
#   _atom basicTag   dictTag radical POSTag RTag  ETag
# 0     痛      CHN  SYM_UNIT       疒    a-B  R-B  Sy-B
# 1     1      NUM     OTHER       -    m-B    O     O
# 2     天      CHN     OTHER       大    n-B    O     O
# 3     。     PUNC     OTHER       -    x-B    O     O

# %%
cct.annotedFilePath
# Out:
# 'annotated/01-一般项目/一般项目-110.txt'

# %%
filename = ['01-一般项目/一般项目-',
            '02-病史特点/病史特点-',
            '04-诊疗经过/诊疗经过-',
            '05-出院情况/出院情况-']

types = [item.split('/')[-1].replace('-', '') for item in filename]

cctTrain = []
cctTest  = []

for t in types:
    typeCCT = cctDict[t]
    random.seed(10)
    l = random.sample(range(len(typeCCT)), int(len(typeCCT)*0.75))
    l.sort()
    cctTypeTrain = [typeCCT[idx] for idx in l]
    cctTrain.append(cctTypeTrain)
    cctTypeTest  = [typeCCT[idx] for idx in range(len(typeCCT)) if idx not in l]
    cctTest.append(cctTypeTest)

# %%
print(len(cctTest))
print(len(cctTrain))
# Out:
# 4
# 4

# %% [markdown]
# ---
#
# **Start Here**

# %%
for t in cctTrain:
    for cct in t:
        cct.getAnnotedEntities('RTag')
        cct.coporAnnotation('RTag')
        cct.getAnnotedEntities('ETag')
        cct.coporAnnotation('ETag')

# %%
import numpy as np
import pandas as pd

# %%
DFtrain = pd.DataFrame()
for t in cctTrain:
    for cct in t:
        df = cct.dfFormat.copy()
        df = df.dropna()
        df.loc[len(df)] = np.NaN     ## Trick Here
        DFtrain = DFtrain.append(df) ## Trick Here

# %%
cct1 = cctTrain[0][0]
df = cct1.dfFormat
df.dropna()
# Out:
#    _atom basicTag     dictTag radical POSTag RTag  ETag
# 0      女      CHN       OTHER       女    n-B    O     O
# 1      性      CHN       OTHER       忄    n-I    O     O
# 2      ,     PUNC       OTHER       -    x-B    O     O
# 3      8      NUM       OTHER       -    m-B    O     O
# 4      8      NUM       OTHER       -    m-I    O     O
# 5      岁      CHN       OTHER       山    m-B    O     O
# 6      ,     PUNC       OTHER       -    x-B    O     O
# 7      农      CHN       OTHER       冖    n-B    O     O
# 8      民      CHN       OTHER       氏    n-I    O     O
# 9      ,     PUNC       OTHER       -    x-B    O     O
# 10     双      CHN    SYM_UNIT       又   nr-B    O     O
# 11     滦      CHN       OTHER       氵   nr-I    O     O
# 12     区      CHN       OTHER       匚   nr-I    O     O
# 13     应      CHN       OTHER       广    v-B    O     O
# 14     营      CHN       OTHER       艹    n-B    O     O
# 15     子      CHN       OTHER       子    n-I    O     O
# 16     村      CHN       OTHER       木   zg-B    O     O
# 17     人      CHN       OTHER       人    n-B    O     O
# 18     ,     PUNC       OTHER       -    x-B    O     O
# 19     主      CHN       OTHER       丶    n-B    O     O
# 20     因      CHN  BREAK_UNIT       囗    n-I    O     O
# 21     右      CHN   SITE_UNIT       口    f-B  R-B  Bo-B
# 22     髋      CHN   PART_UNIT       骨    n-B  R-I  Bo-I
# 23     部      CHN   SITE_UNIT       阝    n-I  R-I  Bo-I
# 24     摔      CHN       OTHER       扌    v-B    O     O
# 25     伤      CHN       OTHER       亻    v-I    O     O
# 26     后      CHN   SITE_UNIT       口    f-B    O     O
# 27     疼      CHN    SYM_UNIT       疒    n-B  R-B  Sy-B
# 28     痛      CHN    SYM_UNIT       疒    n-I  R-I  Sy-I
# 29     肿      CHN       OTHER       月    v-B  R-B  Sy-B
# 30     胀      CHN       OTHER       月    v-I  R-I  Sy-I
# 31     ,     PUNC       OTHER       -    x-B    O     O
# 32     活      CHN       OTHER       氵   vn-B    O     O
# 33     动      CHN       OTHER       力   vn-I    O     O
# 34     受      CHN       OTHER       又    v-B    O     O
# 35     限      CHN       OTHER       阝    v-I    O     O
# 36     5      NUM       OTHER       -    x-B    O     O
# 37     小      CHN    SYM_UNIT       小    n-B    O     O
# 38     时      CHN       OTHER       日    n-I    O     O
# 39     于      CHN       OTHER       二    p-B    O     O
# 40     2      NUM       OTHER       -    m-B    O     O
# 41     0      NUM       OTHER       -    m-I    O     O
# 42     1      NUM       OTHER       -    m-I    O     O
# 43     6      NUM       OTHER       -    m-I    O     O
# 44     -     PUNC       OTHER       -    x-B    O     O
# 45     1      NUM       OTHER       -    m-B    O     O
# 46     0      NUM       OTHER       -    m-I    O     O
# 47     -     PUNC       OTHER       -    x-B    O     O
# 48     2      NUM       OTHER       -    m-B    O     O
# 49     9      NUM       OTHER       -    m-I    O     O
# 50     ;     PUNC       OTHER       -    x-B    O     O
# 51     1      NUM       OTHER       -    m-B    O     O
# 52     1      NUM       OTHER       -    m-I    O     O
# 53     :     PUNC       OTHER       -    x-B    O     O
# 54     1      NUM       OTHER       -    m-B    O     O
# 55     2      NUM       OTHER       -    m-I    O     O
# 56     入      CHN       OTHER       入    n-B    O     O
# 57     院      CHN       OTHER       阝    n-I    O     O
# 58     。     PUNC       OTHER       -    x-B    O     O

# %%
DFtrain = DFtrain.reset_index(drop=True)
DFtrain
# Out:
#        _atom basicTag     dictTag radical POSTag RTag  ETag
# 0          女      CHN       OTHER       女    n-B    O     O
# 1          性      CHN       OTHER       忄    n-I    O     O
# 2          ,     PUNC       OTHER       -    x-B    O     O
# 3          8      NUM       OTHER       -    m-B    O     O
# 4          8      NUM       OTHER       -    m-I    O     O
# 5          岁      CHN       OTHER       山    m-B    O     O
# 6          ,     PUNC       OTHER       -    x-B    O     O
# 7          农      CHN       OTHER       冖    n-B    O     O
# 8          民      CHN       OTHER       氏    n-I    O     O
# 9          ,     PUNC       OTHER       -    x-B    O     O
# 10         双      CHN    SYM_UNIT       又   nr-B    O     O
# 11         滦      CHN       OTHER       氵   nr-I    O     O
# 12         区      CHN       OTHER       匚   nr-I    O     O
# 13         应      CHN       OTHER       广    v-B    O     O
# 14         营      CHN       OTHER       艹    n-B    O     O
# 15         子      CHN       OTHER       子    n-I    O     O
# 16         村      CHN       OTHER       木   zg-B    O     O
# 17         人      CHN       OTHER       人    n-B    O     O
# 18         ,     PUNC       OTHER       -    x-B    O     O
# 19         主      CHN       OTHER       丶    n-B    O     O
# 20         因      CHN  BREAK_UNIT       囗    n-I    O     O
# 21         右      CHN   SITE_UNIT       口    f-B  R-B  Bo-B
# 22         髋      CHN   PART_UNIT       骨    n-B  R-I  Bo-I
# 23         部      CHN   SITE_UNIT       阝    n-I  R-I  Bo-I
# 24         摔      CHN       OTHER       扌    v-B    O     O
# 25         伤      CHN       OTHER       亻    v-I    O     O
# 26         后      CHN   SITE_UNIT       口    f-B    O     O
# 27         疼      CHN    SYM_UNIT       疒    n-B  R-B  Sy-B
# 28         痛      CHN    SYM_UNIT       疒    n-I  R-I  Sy-I
# 29         肿      CHN       OTHER       月    v-B  R-B  Sy-B
# ...      ...      ...         ...     ...    ...  ...   ...
# 202047     存      CHN       OTHER       子    v-B    O     O
# 202048     在      CHN       OTHER       土    v-I    O     O
# 202049     。     PUNC       OTHER       -    x-B    O     O
# 202050     K      ENG       OTHER       -  eng-B  R-B  Ch-B
# 202051     e      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202052     r      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202053     n      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202054     i      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202055     n      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202056     g      ENG        UNIT       -  eng-I  R-I  Ch-I
# 202057     征      CHN       OTHER       彳    v-B  R-I  Ch-I
# 202058     阴      CHN       OTHER       阝    n-B    O     O
# 202059     性      CHN       OTHER       忄    n-I    O     O
# 202060     ,     PUNC       OTHER       -    x-B    O     O
# 202061     双      CHN    SYM_UNIT       又    m-B  R-B  Ch-B
# 202062     侧      CHN   SITE_UNIT       亻    v-B  R-I  Ch-I
# 202063     B      ENG       OTHER       -  eng-B  R-I  Ch-I
# 202064     a      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202065     b      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202066     i      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202067     n      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202068     s      ENG        UNIT       -  eng-I  R-I  Ch-I
# 202069     k      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202070     i      ENG       OTHER       -  eng-I  R-I  Ch-I
# 202071     征      CHN       OTHER       彳    j-B  R-I  Ch-I
# 202072     均      CHN       OTHER       土    j-I    O     O
# 202073     阴      CHN       OTHER       阝    n-B    O     O
# 202074     性      CHN       OTHER       忄    n-I    O     O
# 202075     。     PUNC       OTHER       -    x-B    O     O
# 202076   NaN      NaN         NaN     NaN    NaN  NaN   NaN
#
# [202077 rows x 7 columns]

# %%
import time

def getTrainData(cctTrain, cols= None, Path = None):
    ## TODO
    ## Too slow here.
    for t in cctTrain:
        for cct in t:
            cct.getAnnotedEntities('RTag')
            cct.coporAnnotation('RTag')
            cct.getAnnotedEntities('ETag')
            cct.coporAnnotation('ETag')
            #cct.outputCols = cols
    DFtrain = pd.DataFrame()
    for t in cctTrain:
        for cct in t:
            df = cct.dfFormat.copy()
            df = df.dropna()
            df.loc[len(df)] = np.NaN     ## Trick Here
            DFtrain = DFtrain.append(df) ## Trick Here
    DFtrain = DFtrain.reset_index(drop=True)
    DFtrain.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', 
                   header = False, index = False )


trainDataPara = {'cols': ['_atom', 'basicTag', 'dictTag', 'POSTag', 'ETag'],
                 'Path':'demo/train.txt'}

btime = time.clock()
getTrainData(cctTrain, **trainDataPara)
etime = time.clock()
etime - btime
# Out:
# 20.316196999999995

# %% [markdown]
# ### Test Data

# %%
import pickle

cctListPath = 'pkldata/2017-10-23/CCT_List.p'
cctDictPath = 'pkldata/2017-10-23/CCT_Dict.p'

with open(cctListPath, 'rb') as handle:
    cctList = pickle.load(handle)
    
with open(cctDictPath, 'rb') as handle:
    cctDict = pickle.load(handle)

cctTrain = []
cctTest  = []

for t in types:
    typeCCT = cctDict[t]
    random.seed(10)
    l = random.sample(range(len(typeCCT)), int(len(typeCCT)*0.75))
    l.sort()
    cctTypeTrain = [typeCCT[idx] for idx in l]
    cctTrain.append(cctTypeTrain)
    cctTypeTest  = [typeCCT[idx] for idx in range(len(typeCCT)) if idx not in l]
    cctTest.append(cctTypeTest)

# %%
'''
for t in cctTest:
    for cct in t:
        cct.getAnnotedEntities('RTag')
        cct.coporAnnotation('RTag')
        cct.getAnnotedEntities('ETag')
        cct.coporAnnotation('ETag')
'''


DFtest = pd.DataFrame()
for t in cctTest:
    for cct in t:
        df = cct.dfFormat.copy()
        df = df.dropna()
        df.loc[len(df)] = np.NaN     ## Trick Here
        DFtest = DFtest.append(df)   ## Trick Here

DFtest = DFtest.reset_index(drop=True)
DFtest
# Out:
#       _atom basicTag     dictTag radical POSTag
# 0         中      CHN       OTHER       丨    t-B
# 1         年      CHN       OTHER       干    t-I
# 2         男      CHN       OTHER       田    n-B
# 3         性      CHN       OTHER       忄    n-I
# 4         ,     PUNC       OTHER       -    x-B
# 5         4      NUM       OTHER       -    m-B
# 6         9      NUM       OTHER       -    m-I
# 7         岁      CHN       OTHER       山    m-B
# 8         ,     PUNC       OTHER       -    x-B
# 9         主      CHN       OTHER       丶    n-B
# 10        因      CHN  BREAK_UNIT       囗    n-I
# 11        :     PUNC       OTHER       -    x-B
# 12        腹      CHN   PART_UNIT       月    n-B
# 13        痛      CHN    SYM_UNIT       疒    n-I
# 14        、     PUNC       OTHER       -    x-B
# 15        腹      CHN   PART_UNIT       月    v-B
# 16        胀      CHN       OTHER       月    v-I
# 17        2      NUM       OTHER       -    m-B
# 18        个      CHN    CHN_UNIT       丨    m-B
# 19        月      CHN       OTHER       月    m-B
# 20        ,     PUNC       OTHER       -    x-B
# 21        停      CHN       OTHER       亻    v-B
# 22        止      CHN       OTHER       止    v-I
# 23        排      CHN       OTHER       扌    v-B
# 24        便      CHN       OTHER       亻    v-I
# 25        3      NUM       OTHER       -    m-B
# 26        天      CHN       OTHER       大    n-B
# 27        ,     PUNC       OTHER       -    x-B
# 28        停      CHN       OTHER       亻    v-B
# 29        止      CHN       OTHER       止    v-I
# ...     ...      ...         ...     ...    ...
# 66328     触      CHN       OTHER       角    v-B
# 66329     及      CHN       OTHER       又    v-I
# 66330     ,     PUNC       OTHER       -    x-B
# 66331     移      CHN       OTHER       禾    n-B
# 66332     动      CHN       OTHER       力    n-I
# 66333     性      CHN       OTHER       忄    n-I
# 66334     浊      CHN       OTHER       氵    n-B
# 66335     音      CHN       OTHER       音    n-I
# 66336     阴      CHN       OTHER       阝    n-B
# 66337     性      CHN       OTHER       忄    n-I
# 66338     ,     PUNC       OTHER       -    x-B
# 66339     双      CHN    SYM_UNIT       又    n-B
# 66340     下      CHN   SITE_UNIT       一    n-I
# 66341     肢      CHN   PART_UNIT       月    n-I
# 66342     无      CHN    NON_UNIT       无    v-B
# 66343     水      CHN       OTHER       水    n-B
# 66344     肿      CHN       OTHER       月    n-I
# 66345     ,     PUNC       OTHER       -    x-B
# 66346     神      CHN       OTHER       礻    l-B
# 66347     经      CHN       OTHER       纟    l-I
# 66348     系      CHN       OTHER       糸    l-I
# 66349     统      CHN       OTHER       纟    l-I
# 66350     查      CHN       OTHER       木   nr-B
# 66351     体      CHN       OTHER       亻   nr-I
# 66352     未      CHN    NON_UNIT       木    i-B
# 66353     见      CHN  BREAK_UNIT       见    i-I
# 66354     异      CHN       OTHER       廾    i-I
# 66355     常      CHN       OTHER       巾    i-I
# 66356     。     PUNC       OTHER       -    x-B
# 66357   NaN      NaN         NaN     NaN    NaN
#
# [66358 rows x 5 columns]

# %%
def getTestData(cctTest, cols, Path):
    DFtest = pd.DataFrame()
    for t in cctTest:
        for cct in t:
            cct.outputCols = cols
            df = cct.dfFormat.copy()
            df = df.dropna()
            df.loc[len(df)] = np.NaN     ## Trick Here
            DFtest = DFtest.append(df)   ## Trick Here
    DFtest = DFtest.reset_index(drop=True)
    DFtest.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', 
                  header = False, index = False )
    
def getTestData2(cctTest, cols, Path, resultPath):
    results = splitResult(resultPath)
    cctTestList = sum(cctTest, [])
    if len(cctTestList) != len(results):
        return "Bad Performance, Not Match!!!"
    for idx in range(len(cctTestList)):
        cct    = cctTestList[idx]
        result = results[idx]
        cct.outputCols = cols 
        cct.coporResult(result=result[1], newTag= eType) ## TODO
        cct.score = result[0]
        cct.getLearnedEntities(eType)
    for cct in cctTestList:
        cct.getAnnotedEntities('ETag')
        cct.getLearnedEntities('ETag')
    getTestData(cctTest, cols, Path)
    
    
testDataPara = {'cols': ['_atom', 'basicTag', 'dictTag', 'POSTag'],
                 'Path':'demo/test.txt'}

btime = time.clock()
getTrainData(cctTrain, **testDataPara)
etime = time.clock()
etime - btime
# Out:
# 20.655392

# %% [markdown]
# ### To Evaluate Performance - There is a unique notebook for it

# %%
cols = ['_atom', 'basicTag', 'dictTag', 'POSTag']
filePath = 'eval/Test.txt'
DFtest.to_csv(filePath, columns = cols,
              sep = '\t', encoding = 'utf=8', 
              header = False, index = False )

# %% [markdown]
# ## Generate LoadData

# %%
## Path for Dict
import random
import time
import pickle
import pandas as pd
import numpy as np

pklDictPath = 'pkldata/2017-10-23/CCT_Dict.p'


filename = ['01-一般项目/一般项目-',
            '02-病史特点/病史特点-',
            '04-诊疗经过/诊疗经过-',
            '05-出院情况/出院情况-']

types = [item.split('/')[-1].replace('-', '') for item in filename]

def loadData(pklDictPath, seed):
    with open(pklDictPath, 'rb') as handle:
        cctDict = pickle.load(handle)
    
    cctTrain = []
    cctTest  = []
    n = 0
    for t in types:
        n+=1
        typeCCT = cctDict[t]
        random.seed(n*seed)
        l = random.sample(range(len(typeCCT)), int(len(typeCCT)*0.75))
        l.sort()
        cctTypeTrain = [typeCCT[idx] for idx in l]
        cctTrain.append(cctTypeTrain)
        cctTypeTest  = [typeCCT[idx] for idx in range(len(typeCCT)) if idx not in l]
        cctTest.append(cctTypeTest)
    return cctTrain, cctTest

def getTrainData(cctTrain, cols= None, Path = None):
    ## TODO
    ## Too slow here.
    for t in cctTrain:
        for cct in t:
            cct.getAnnotedEntities('RTag')
            cct.coporAnnotation('RTag')
            cct.getAnnotedEntities('ETag')
            cct.coporAnnotation('ETag')
            cct.outputCols = cols
    DFtrain = pd.DataFrame()
    for t in cctTrain:
        for cct in t:
            df = cct.dfFormat.copy()
            df = df.dropna()
            df.loc[len(df)] = np.NaN     ## Trick Here
            DFtrain = DFtrain.append(df) ## Trick Here
    DFtrain = DFtrain.reset_index(drop=True)
    DFtrain.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', header = False, index = False )

    
def getTestData(cctTest, cols, Path):
    DFtest = pd.DataFrame()
    for t in cctTest:
        for cct in t:
            cct.outputCols = cols
            df = cct.dfFormat.copy()
            df = df.dropna()
            df.loc[len(df)] = np.NaN     ## Trick Here
            DFtest = DFtest.append(df)  ## Trick Here
    DFtest = DFtest.reset_index(drop=True)
    DFtest.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', 
                  header = False, index = False )

# %%
btime = time.clock()
cctTrain, cctTest = loadData(pklDictPath, 10)
etime = time.clock()
print(etime - btime)
print([len(i) for i in cctTrain])
print([len(i) for i in cctTest])
# Out:
# 1.700882
# [225, 225, 224, 224]
# [75, 75, 75, 75]

# %%
from loaddata import getTestData2
from splitresult import splitResult

testCols1 = ['_atom', 'basicTag' ]

testCols2 = ['_atom', 'basicTag' ] + ['RTag']


def getTestData2(cctTest, cols, Path, resultPath):
    results = splitResult(resultPath)
    cctTestList = sum(cctTest, [])
    if len(cctTestList) != len(results):
        return "Bad Performance, Not Match!!!"
    
    DFtest = pd.DataFrame()
    for idx in range(len(cctTestList)):
        cct    = cctTestList[idx]
        result = results[idx]
        #cct.outputCols = cols 
        df0 = cct.dfFormat
        cct.coporResult(result[1], newTag= 'RTag') ## TODO
        
        #print(cct.dfFormat)
        #cct.score = result[0]
        #cct.getLearnedEntities('RTag')
        cct.outputCols = cols
        df = cct.dfFormat.copy()
        df = df.dropna()
        df.loc[len(df)] = np.NaN     ## Trick Here
        DFtest = DFtest.append(df)   ## Trick Here
        break
    DFtest = DFtest.reset_index(drop=True)
    DFtest.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', 
                  header = False, index = False )
    return df

# %%
RPath = '/Users/floyd/Desktop/Research/NER-CRF/tutorial/models/2ab/output/testDataResult1.txt'

getTestData2(cctTest, cols = testCols2, Path = 'demo/test2.txt', resultPath = RPath )
# Out:
#    _atom basicTag     dictTag radical POSTag RTag
# 0      中      CHN       OTHER       丨    t-B    O
# 1      年      CHN       OTHER       干    t-I    O
# 2      男      CHN       OTHER       田    n-B    O
# 3      性      CHN       OTHER       忄    n-I    O
# 4      ,     PUNC       OTHER       -    x-B    O
# 5      4      NUM       OTHER       -    m-B    O
# 6      9      NUM       OTHER       -    m-I    O
# 7      岁      CHN       OTHER       山    m-B    O
# 8      ,     PUNC       OTHER       -    x-B    O
# 9      主      CHN       OTHER       丶    n-B    O
# 10     因      CHN  BREAK_UNIT       囗    n-I    O
# 11     :     PUNC       OTHER       -    x-B    O
# 12     腹      CHN   PART_UNIT       月    n-B  R-B
# 13     痛      CHN    SYM_UNIT       疒    n-I  R-I
# 14     、     PUNC       OTHER       -    x-B    O
# 15     腹      CHN   PART_UNIT       月    v-B  R-B
# 16     胀      CHN       OTHER       月    v-I  R-I
# 17     2      NUM       OTHER       -    m-B    O
# 18     个      CHN    CHN_UNIT       丨    m-B    O
# 19     月      CHN       OTHER       月    m-B    O
# 20     ,     PUNC       OTHER       -    x-B    O
# 21     停      CHN       OTHER       亻    v-B    O
# 22     止      CHN       OTHER       止    v-I    O
# 23     排      CHN       OTHER       扌    v-B    O
# 24     便      CHN       OTHER       亻    v-I    O
# 25     3      NUM       OTHER       -    m-B    O
# 26     天      CHN       OTHER       大    n-B    O
# 27     ,     PUNC       OTHER       -    x-B    O
# 28     停      CHN       OTHER       亻    v-B    O
# 29     止      CHN       OTHER       止    v-I    O
# 30     排      CHN       OTHER       扌    n-B    O
# 31     气      CHN       OTHER       气    n-I    O
# 32     2      NUM       OTHER       -    m-B    O
# 33     天      CHN       OTHER       大    n-B    O
# 34     。     PUNC       OTHER       -    x-B    O
# 35     于      CHN       OTHER       二    p-B    O
# 36     2      NUM       OTHER       -    m-B    O
# 37     0      NUM       OTHER       -    m-I    O
# 38     1      NUM       OTHER       -    m-I    O
# 39     6      NUM       OTHER       -    m-I    O
# 40     -     PUNC       OTHER       -    x-B    O
# 41     3      NUM       OTHER       -    x-B    O
# 42     -     PUNC       OTHER       -    x-B    O
# 43     3      NUM       OTHER       -    m-B    O
# 44     0      NUM       OTHER       -    m-I    O
# 45     入      CHN       OTHER       入    n-B    O
# 46     院      CHN       OTHER       阝    n-I    O
# 47     。     PUNC       OTHER       -    x-B    O
# 48   NaN      NaN         NaN     NaN    NaN  NaN

# %%
trainDataPara = {'cols': ['_atom', 'basicTag', 'dictTag', 'POSTag', 'ETag'],
                 'Path':'demo/train.txt'}

btime = time.clock()
df = getTrainData(cctTrain, **trainDataPara)
etime = time.clock()
etime - btime
# Out:
# 18.91218

# %%
testDataPara = {'cols': ['_atom', 'basicTag', 'dictTag', 'POSTag' ],
                 'Path':'demo/test.txt'}

btime = time.clock()
getTestData(cctTest, **testDataPara)
etime = time.clock()
print(etime - btime)
# Out:
# 1.5204149999999998

# %%
#getTestData2(cctTest, cols = testCols2, Path = 'demo/test2.txt', resultPath = 'textDataResult1.txt')

# %%
def getTestData2(cctTest, cols, Path, resultPath):
    results = splitResult(resultPath)
    cctTestList = sum(cctTest, [])
    if len(cctTestList) != len(results):
        return "Bad Performance, Not Match!!!"
    
    DFtest = pd.DataFrame()
    for idx in range(len(cctTestList)):
        cct    = cctTestList[idx]
        result = results[idx]
        cct.outputCols = cols 
        cct.coporResult(result=result[1], newTag= 'RTag') ## TODO
        #print(cct.dfFormat)
        #cct.score = result[0]
        #cct.getLearnedEntities('RTag')
        cct.outputCols = cols
        df = cct.dfFormat.copy()
        df = df.dropna()
        df.loc[len(df)] = np.NaN     ## Trick Here
        DFtest = DFtest.append(df)   ## Trick Here
        break
    DFtest = DFtest.reset_index(drop=True)
    DFtest.to_csv(Path, columns = cols, sep = '\t', encoding = 'utf=8', 
                  header = False, index = False )
    return result[1]

# %%
getTestData2(cctTest, cols = testCols2, Path = 'demo/test2.txt', resultPath = 'textDataResult1.txt')
# Out:
#    _atom basicTag  RTag      Result             0             1
# 0      中      CHN     O  O/0.999196  R-B/0.000802  R-I/0.000002
# 1      年      CHN     O  O/0.999751  R-B/0.000004  R-I/0.000245
# 2      男      CHN     O  O/0.999996  R-B/0.000002  R-I/0.000002
# 3      性      CHN     O  O/0.999999  R-B/0.000000  R-I/0.000001
# 4      ,     PUNC     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 5      4      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 6      9      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 7      岁      CHN     O  O/0.999974  R-B/0.000025  R-I/0.000001
# 8      ,     PUNC     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 9      主      CHN     O  O/0.999994  R-B/0.000006  R-I/0.000000
# 10     因      CHN     O  O/0.999993  R-B/0.000002  R-I/0.000006
# 11     :     PUNC     O  O/0.999999  R-B/0.000001  R-I/0.000000
# 12     腹      CHN     O  O/0.004280  R-B/0.995718  R-I/0.000002
# 13     痛      CHN     O  O/0.004832  R-B/0.000035  R-I/0.995133
# 14     、     PUNC     O  O/0.999894  R-B/0.000012  R-I/0.000094
# 15     腹      CHN     O  O/0.002382  R-B/0.997523  R-I/0.000095
# 16     胀      CHN     O  O/0.003533  R-B/0.000151  R-I/0.996316
# 17     2      NUM     O  O/0.997948  R-B/0.000020  R-I/0.002032
# 18     个      CHN     O  O/0.999869  R-B/0.000012  R-I/0.000118
# 19     月      CHN     O  O/0.999913  R-B/0.000003  R-I/0.000085
# 20     ,     PUNC     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 21     停      CHN     O  O/0.999596  R-B/0.000403  R-I/0.000001
# 22     止      CHN     O  O/0.999614  R-B/0.000044  R-I/0.000342
# 23     排      CHN     O  O/0.999001  R-B/0.000634  R-I/0.000365
# 24     便      CHN     O  O/0.987307  R-B/0.011578  R-I/0.001115
# 25     3      NUM     O  O/0.999999  R-B/0.000000  R-I/0.000001
# 26     天      CHN     O  O/0.999997  R-B/0.000003  R-I/0.000000
# 27     ,     PUNC     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 28     停      CHN     O  O/0.999942  R-B/0.000057  R-I/0.000000
# 29     止      CHN     O  O/0.999988  R-B/0.000001  R-I/0.000011
# 30     排      CHN     O  O/0.999995  R-B/0.000004  R-I/0.000001
# 31     气      CHN     O  O/0.999965  R-B/0.000030  R-I/0.000006
# 32     2      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 33     天      CHN     O  O/0.999996  R-B/0.000004  R-I/0.000000
# 34     。     PUNC     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 35     于      CHN     O  O/0.999943  R-B/0.000057  R-I/0.000000
# 36     2      NUM     O  O/0.999999  R-B/0.000001  R-I/0.000000
# 37     0      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 38     1      NUM     O  O/0.999996  R-B/0.000004  R-I/0.000000
# 39     6      NUM     O  O/0.999989  R-B/0.000003  R-I/0.000007
# 40     -     PUNC     O  O/0.999954  R-B/0.000007  R-I/0.000038
# 41     3      NUM     O  O/0.999985  R-B/0.000000  R-I/0.000014
# 42     -     PUNC     O  O/0.999972  R-B/0.000003  R-I/0.000025
# 43     3      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 44     0      NUM     O  O/1.000000  R-B/0.000000  R-I/0.000000
# 45     入      CHN     O  O/0.999999  R-B/0.000001  R-I/0.000000
# 46     院      CHN     O  O/0.999998  R-B/0.000001  R-I/0.000000
# 47     。     PUNC     O  O/0.999999  R-B/0.000001  R-I/0.000000
# 48   NaN      NaN  None         NaN           NaN           NaN

# %%
RPath = '/Users/floyd/Desktop/Research/NER-CRF/tutorial/models/2ab/output/testDataResult1.txt'

btime = time.clock()
cctTrain, cctTest = loadData(pklDictPath, 10)
etime = time.clock()
print(etime - btime)
print([len(i) for i in cctTrain])
print([len(i) for i in cctTest])

results = splitResult(RPath)
cctTestList = sum(cctTest, [])
len(cctTestList) != len(results)
# Out:
# 1.4418229999999994
# [225, 225, 224, 224]
# [75, 75, 75, 75]
# False

# %%
cct = cctTestList[0]
cct.dfFormat
# Out:
#    _atom basicTag     dictTag radical POSTag
# 0      中      CHN       OTHER       丨    t-B
# 1      年      CHN       OTHER       干    t-I
# 2      男      CHN       OTHER       田    n-B
# 3      性      CHN       OTHER       忄    n-I
# 4      ,     PUNC       OTHER       -    x-B
# 5      4      NUM       OTHER       -    m-B
# 6      9      NUM       OTHER       -    m-I
# 7      岁      CHN       OTHER       山    m-B
# 8      ,     PUNC       OTHER       -    x-B
# 9      主      CHN       OTHER       丶    n-B
# 10     因      CHN  BREAK_UNIT       囗    n-I
# 11     :     PUNC       OTHER       -    x-B
# 12     腹      CHN   PART_UNIT       月    n-B
# 13     痛      CHN    SYM_UNIT       疒    n-I
# 14     、     PUNC       OTHER       -    x-B
# 15     腹      CHN   PART_UNIT       月    v-B
# 16     胀      CHN       OTHER       月    v-I
# 17     2      NUM       OTHER       -    m-B
# 18     个      CHN    CHN_UNIT       丨    m-B
# 19     月      CHN       OTHER       月    m-B
# 20     ,     PUNC       OTHER       -    x-B
# 21     停      CHN       OTHER       亻    v-B
# 22     止      CHN       OTHER       止    v-I
# 23     排      CHN       OTHER       扌    v-B
# 24     便      CHN       OTHER       亻    v-I
# 25     3      NUM       OTHER       -    m-B
# 26     天      CHN       OTHER       大    n-B
# 27     ,     PUNC       OTHER       -    x-B
# 28     停      CHN       OTHER       亻    v-B
# 29     止      CHN       OTHER       止    v-I
# 30     排      CHN       OTHER       扌    n-B
# 31     气      CHN       OTHER       气    n-I
# 32     2      NUM       OTHER       -    m-B
# 33     天      CHN       OTHER       大    n-B
# 34     。     PUNC       OTHER       -    x-B
# 35     于      CHN       OTHER       二    p-B
# 36     2      NUM       OTHER       -    m-B
# 37     0      NUM       OTHER       -    m-I
# 38     1      NUM       OTHER       -    m-I
# 39     6      NUM       OTHER       -    m-I
# 40     -     PUNC       OTHER       -    x-B
# 41     3      NUM       OTHER       -    x-B
# 42     -     PUNC       OTHER       -    x-B
# 43     3      NUM       OTHER       -    m-B
# 44     0      NUM       OTHER       -    m-I
# 45     入      CHN       OTHER       入    n-B
# 46     院      CHN       OTHER       阝    n-I
# 47     。     PUNC       OTHER       -    x-B

# %%
result = results[0][1]
result
cct.outputCols
# Out:
# ['_atom', 'basicTag']

# %%
cct.coporResult(result, newTag = 'RTag')
cct.dfFormat
# Out:
#    _atom basicTag     dictTag radical POSTag RTag
# 0      中      CHN       OTHER       丨    t-B    O
# 1      年      CHN       OTHER       干    t-I    O
# 2      男      CHN       OTHER       田    n-B    O
# 3      性      CHN       OTHER       忄    n-I    O
# 4      ,     PUNC       OTHER       -    x-B    O
# 5      4      NUM       OTHER       -    m-B    O
# 6      9      NUM       OTHER       -    m-I    O
# 7      岁      CHN       OTHER       山    m-B    O
# 8      ,     PUNC       OTHER       -    x-B    O
# 9      主      CHN       OTHER       丶    n-B    O
# 10     因      CHN  BREAK_UNIT       囗    n-I    O
# 11     :     PUNC       OTHER       -    x-B    O
# 12     腹      CHN   PART_UNIT       月    n-B  R-B
# 13     痛      CHN    SYM_UNIT       疒    n-I  R-I
# 14     、     PUNC       OTHER       -    x-B    O
# 15     腹      CHN   PART_UNIT       月    v-B  R-B
# 16     胀      CHN       OTHER       月    v-I  R-I
# 17     2      NUM       OTHER       -    m-B    O
# 18     个      CHN    CHN_UNIT       丨    m-B    O
# 19     月      CHN       OTHER       月    m-B    O
# 20     ,     PUNC       OTHER       -    x-B    O
# 21     停      CHN       OTHER       亻    v-B    O
# 22     止      CHN       OTHER       止    v-I    O
# 23     排      CHN       OTHER       扌    v-B    O
# 24     便      CHN       OTHER       亻    v-I    O
# 25     3      NUM       OTHER       -    m-B    O
# 26     天      CHN       OTHER       大    n-B    O
# 27     ,     PUNC       OTHER       -    x-B    O
# 28     停      CHN       OTHER       亻    v-B    O
# 29     止      CHN       OTHER       止    v-I    O
# 30     排      CHN       OTHER       扌    n-B    O
# 31     气      CHN       OTHER       气    n-I    O
# 32     2      NUM       OTHER       -    m-B    O
# 33     天      CHN       OTHER       大    n-B    O
# 34     。     PUNC       OTHER       -    x-B    O
# 35     于      CHN       OTHER       二    p-B    O
# 36     2      NUM       OTHER       -    m-B    O
# 37     0      NUM       OTHER       -    m-I    O
# 38     1      NUM       OTHER       -    m-I    O
# 39     6      NUM       OTHER       -    m-I    O
# 40     -     PUNC       OTHER       -    x-B    O
# 41     3      NUM       OTHER       -    x-B    O
# 42     -     PUNC       OTHER       -    x-B    O
# 43     3      NUM       OTHER       -    m-B    O
# 44     0      NUM       OTHER       -    m-I    O
# 45     入      CHN       OTHER       入    n-B    O
# 46     院      CHN       OTHER       阝    n-I    O
# 47     。     PUNC       OTHER       -    x-B    O
